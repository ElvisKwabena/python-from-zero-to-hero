# %%
import pdb

# %%
s=[1,3,4]
y=2
z=3

pdb.set_trace()
result=y+z
print(result)


result1=s+y
print(result1)
# Out:
# --Return--
# None
# > c:\users\elvis\appdata\local\temp\ipykernel_10508\4265298940.py(5)<cell line: 5>()
#
# ipdb> s+y
#     [... skipped 1 hidden frame]
#
# > c:\users\elvis\anaconda3\lib\site-packages\ipython\core\interactiveshell.py(3372)run_code()
#    3370             finally:
#    3371                 # Reset our crash handler in place
# -> 3372                 sys.excepthook = old_excepthook
#    3373         except SystemExit as e:
#    3374             if result is not None:
